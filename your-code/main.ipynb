# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd
import numpy

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:

admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:

admissions.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.index = admissions['Serial No.']
admissions
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
# ...                ...        ...          ...                ...  ...  ...
# 381                381        324          110                  3  3.5  3.5
# 382                382        325          107                  3  3.0  3.5
# 383                383        330          116                  4  5.0  4.5
# 384                384        312          103                  3  3.5  4.0
# 385                385        333          117                  4  5.0  4.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90
# ...          ...       ...              ...
# 381         9.04         1             0.82
# 382         9.11         1             0.84
# 383         9.45         1             0.91
# 384         8.78         0             0.67
# 385         9.66         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
admissions[['GRE Score','CGPA']]
# Out:
#             GRE Score  CGPA
# Serial No.
# 1                 337  9.65
# 2                 316  8.00
# 3                 322  8.67
# 4                 314  8.21
# 5                 330  9.34
# ...               ...   ...
# 381               324  9.04
# 382               325  9.11
# 383               330  9.45
# 384               312  8.78
# 385               333  9.66
#
# [385 rows x 2 columns]

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
df_admissions = admissions.set_index(['GRE Score','CGPA'])
df_admissions
# Out:
#                 Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# GRE Score CGPA
# 337       9.65           1          118                  4  4.5  4.5
# 316       8.00           2          104                  3  3.0  3.5
# 322       8.67           3          110                  3  3.5  2.5
# 314       8.21           4          103                  2  2.0  3.0
# 330       9.34           5          115                  5  4.5  3.0
# ...                    ...          ...                ...  ...  ...
# 324       9.04         381          110                  3  3.5  3.5
# 325       9.11         382          107                  3  3.0  3.5
# 330       9.45         383          116                  4  5.0  4.5
# 312       8.78         384          103                  3  3.5  4.0
# 333       9.66         385          117                  4  5.0  4.0
#
#                 Research  Chance of Admit
# GRE Score CGPA
# 337       9.65         1             0.92
# 316       8.00         1             0.72
# 322       8.67         1             0.80
# 314       8.21         0             0.65
# 330       9.34         1             0.90
# ...                  ...              ...
# 324       9.04         1             0.82
# 325       9.11         1             0.84
# 330       9.45         1             0.91
# 312       8.78         0             0.67
# 333       9.66         1             0.95
#
# [385 rows x 7 columns]

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
admissions[(admissions.CGPA>9)&(admissions.Research)]
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 5                    5        330          115                  5  4.5  3.0
# 11                  11        328          112                  4  4.0  4.5
# 20                  20        328          116                  5  5.0  5.0
# 21                  21        334          119                  5  5.0  4.5
# ...                ...        ...          ...                ...  ...  ...
# 380                380        329          111                  4  4.5  4.0
# 381                381        324          110                  3  3.5  3.5
# 382                382        325          107                  3  3.0  3.5
# 383                383        330          116                  4  5.0  4.5
# 385                385        333          117                  4  5.0  4.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 5           9.34         1             0.90
# 11          9.10         1             0.78
# 20          9.50         1             0.94
# 21          9.70         1             0.95
# ...          ...       ...              ...
# 380         9.23         1             0.89
# 381         9.04         1             0.82
# 382         9.11         1             0.84
# 383         9.45         1             0.91
# 385         9.66         1             0.95
#
# [101 rows x 9 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:

admissions[(admissions.CGPA>9)& (admissions.SOP<3.5)]['Chance of Admit']
# Out:
# Serial No.
# 29     0.91
# 63     0.61
# 141    0.83
# 218    0.82
# 382    0.84
# Name: Chance of Admit, dtype: float64

# %%
admissions[(admissions.CGPA>9)& (admissions.SOP<3.5)]['Chance of Admit'].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    media = col.mean()
    std = col.std()
    return (col-media)/std
    
    # Your code here:
#standardize(admissions.CGPA)

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
CGPA_std = standardize(admissions.CGPA)
GRE_std = standardize(admissions['GRE Score'])
LOR_std = standardize(admissions.LOR)

# %%
type(LOR_std)
admissions['CGPA_std'] = CGPA_std
admissions['GRE_std']  = GRE_std
admissions['LOR_std'] = LOR_std
#print(CPGA_std,GRE_std,LOR_std)

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])
decision_choice
# Out:
# ['LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std']

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
deciding_column = admissions.lookup(admissions.index, decision_choice)
deciding_column
# Out:
# array([ 1.19164669, -0.99121092, -1.03816607, -0.23639072, -0.48071288,
#        -0.65919752,  0.6341935 , -2.15307245,  0.00482929,  1.19164669,
#         0.83486279, -0.99121092, -0.65919752, -0.23639072,  0.02314472,
#        -0.99121092,  0.10965653, -1.18802069,  0.71523924,  1.74909988,
#         1.49384557,  1.99690969,  0.07674031, -1.82124442, -1.8801152 ,
#        -0.58243798, -1.44755613, -0.49319082,  1.33288289,  1.66489629,
#         1.23431012,  0.28268016, -0.32718412, -1.44755613, -2.15307245,
#        -1.48923102, -0.99121092, -1.03816607, -0.16117741,  0.6341935 ,
#         0.6341935 ,  0.83486279,  1.16687619,  1.92640464,  1.74909988,
#        -0.32718412, -0.49319082,  0.07674031, -0.48071288, -1.03816607,
#         0.07674031, -0.48071288, -0.0633671 , -1.62057976, -1.59561926,
#        -1.59561926, -0.6689498 , -0.84197343, -0.48071288, -0.16117741,
#         0.17083599,  0.53605073, -0.48071288,  0.07123197,  0.6341935 ,
#         0.6341935 ,  1.74909988,  1.6668692 ,  1.41588624,  0.73525877,
#         0.50284939,  1.06128649, -0.48071288, -1.59561926, -1.59561926,
#        -1.96662702, -0.48071288,  1.49888959,  1.19164669,  1.19164669,
#         1.19164669,  0.10443331, -0.29398278,  0.02314472,  0.07674031,
#         0.10965653, -1.5556337 , -0.48071288, -1.19041896, -1.03816607,
#        -1.03816607, -0.99121092,  1.23431012,  1.32082194,  0.6341935 ,
#         0.07674031, -0.40941435, -0.23639072, -0.21097942, -0.48071288,
#        -0.0633671 ,  1.19164669,  1.43248691,  1.23431012, -1.10150887,
#        -1.01499706,  0.6341935 , -1.36104431, -0.06157339, -0.49592617,
#        -0.58243798,  0.03803063, -1.03816607, -1.79360339,  0.07674031,
#         1.58035738,  1.19164669, -0.58243798, -0.62599618, -1.36104431,
#         0.10443331,  1.20007753, -1.59561926, -0.48071288,  1.24987954,
#         1.93050701,  1.19164669,  0.54221561,  1.13367485,  0.28704068,
#        -0.48071288,  0.80166145,  0.86806413,  1.06128649,  0.07674031,
#         0.07674031,  2.19611773,  0.60245341,  0.07123197, -1.03816607,
#        -0.48071288,  0.07674031, -0.5595935 ,  1.3826849 ,  1.13367485,
#         0.36919198,  0.25383934,  0.48624872, -0.40941435, -0.14987891,
#        -1.03816607, -0.75880154, -1.15721762, -1.59561926, -0.48071288,
#         0.10965653,  0.02314472,  0.68545676,  0.6341935 , -1.2745325 ,
#        -0.32290254, -1.32322432, -0.48071288, -0.40941435,  1.19164669,
#         0.45570379,  0.54221561,  0.6341935 ,  0.45304738,  1.06128649,
#         0.73525877, -0.48071288, -0.54299283, -0.7256002 , -0.29398278,
#         0.07674031,  0.33684269,  1.19164669,  0.13763465,  1.58035738,
#         1.26648021,  0.93446681,  0.54221561,  0.56925207,  1.6668692 ,
#        -0.0633671 , -0.12797607, -0.5595935 , -0.44338881, -0.32290254,
#        -0.09477473, -0.2275801 ,  2.17951706,  1.49384557, -0.09477473,
#        -0.48071288, -0.48071288, -0.58243798, -1.01499706,  0.6341935 ,
#         0.6341935 ,  0.90126547,  1.76450031,  1.40733375,  1.74909988,
#         1.26648021,  1.10047351,  0.8846648 ,  0.62872742, -0.29398278,
#         0.6341935 , -0.0633671 , -0.75546161, -1.01499706, -1.03816607,
#        -0.92848524,  0.07674031,  0.62872742, -0.32290254, -1.03816607,
#        -0.54299283, -1.10150887,  1.18347686,  1.0506715 ,  0.95106748,
#         1.06128649, -0.58243798, -1.53406794, -0.48071288, -1.59561926,
#        -0.48071288,  0.73525877, -0.23639072, -1.03816607,  0.220638  ,
#         0.07674031,  0.62872742,  0.6341935 , -1.03816607, -0.48071288,
#         0.10965653,  1.79770165,  0.36919198,  1.19164669,  0.6341935 ,
#         0.62872742,  1.23327887,  0.07674031, -0.84180489, -0.75546161,
#         0.32024202,  0.71523924, -1.03816607, -0.40941435, -0.70899953,
#         1.74909988,  1.74909988, -0.62599618, -1.59561926, -2.15307245,
#        -0.97461025, -0.14987891, -0.48071288,  1.06128649, -0.48071288,
#         0.07674031, -1.10150887, -0.49592617,  0.85146346,  0.32024202,
#        -0.48071288,  2.01291646,  1.23431012,  0.6341935 ,  0.62872742,
#        -0.23639072,  0.07674031, -0.84197343, -1.20701963, -1.04101293,
#        -0.40941435, -0.0633671 ,  0.02314472,  0.12103398,  0.28268016,
#         1.19164669,  0.07674031, -0.99121092,  0.27044001, -0.24418077,
#         0.07674031, -1.59561926,  0.36919198,  0.54221561,  0.66885609,
#        -0.40941435, -0.48071288,  0.28268016,  0.6341935 ,  0.66885609,
#        -1.36104431, -0.87500623, -1.2236203 , -0.97461025, -1.59561926,
#         0.15423532, -0.16117741,  0.6341935 , -0.23639072, -1.01499706,
#        -0.14987891,  0.90126547, -1.53406794, -1.8801152 ,  0.28704068,
#        -1.17381829, -0.48071288, -1.59561926, -1.03816607,  0.07674031,
#         0.08783264,  0.32024202,  1.32082194,  0.23723867,  0.10443331,
#        -0.2275801 ,  0.07674031, -0.59279484, -0.77540221, -2.08685514,
#        -1.93744911, -1.58883504, -2.71052564, -1.59561926, -0.92480824,
#        -0.54299283,  0.12103398, -1.18802069, -1.44755613, -1.70709157,
#         0.02314472,  0.6341935 , -1.36104431, -1.58883504, -0.26078144,
#         1.74909988,  1.49384557,  1.83989283, -0.3935868 ,  0.50284939,
#        -0.48071288,  1.19164669, -0.49592617, -1.59561926, -0.48071288,
#        -1.03816607, -0.48071288,  1.69809763, -0.09477473, -0.14987891,
#        -1.03816607, -1.93744911, -1.59561926, -1.57223437, -0.49592617,
#         0.45570379,  0.12103398,  0.6341935 , -1.44755613,  2.01291646,
#         1.58035738, -1.2745325 , -0.84197343, -1.59561926,  0.6341935 ,
#        -0.23639072,  0.08783264,  0.86806413, -0.48071288,  1.0506715 ,
#         0.73525877,  0.07674031,  1.19164669, -0.40941435,  1.76450031])

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:
admissions['deciding_column'] = deciding_column
admissions['decision'] = admissions['deciding_column'].map(lambda x: 1 if x > 0.8 else 0)
admissions.keys()
# Out:
# Index(['serial_no', 'gre_score', 'toefl_score', 'university_rating', 'sop',
#        'lor', 'cgpa', 'research', 'chance_of_admit', 'cgpa_std', 'gre_std',
#        'lor_std', 'deciding_column', 'adjusted_gre', 'decision'],
#       dtype='object')

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:
admissions.groupby(['decision']).size()
# Out:
# decision
# 0    303
# 1     82
# dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:
admissions.columns = admissions.columns.str.replace(" ","_").str.lower().str.replace(r'[.]\s?',r'',regex=True)
admissions.columns
# Out:
# Index(['serial_no', 'gre_score', 'toefl_score', 'university_rating', 'sop',
#        'lor', 'cgpa', 'research', 'chance_of_admit', 'cgpa_std', 'gre_std',
#        'lor_std', 'deciding_column'],
#       dtype='object')

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:
admissions["adjusted_gre"] = numpy.where(admissions["university_rating"] >=4, admissions["gre_score"] + 10, admissions["gre_score"])
admissions.head(3)
# Out:
#             serial_no  gre_score  toefl_score  university_rating  sop  lor  \
# Serial No.
# 1                   1        337          118                  4  4.5  4.5
# 2                   2        316          104                  3  3.0  3.5
# 3                   3        322          110                  3  3.5  2.5
#
#             cgpa  research  chance_of_admit  cgpa_std   gre_std   lor_std  \
# Serial No.
# 1           9.65         1             0.92  1.747900  1.753381  1.191647
# 2           8.00         1             0.72 -0.991211 -0.063367  0.076740
# 3           8.67         1             0.80  0.121034  0.455704 -1.038166
#
#             deciding_column  adjusted_gre
# Serial No.
# 1                  1.191647           347
# 2                 -0.991211           316
# 3                 -1.038166           322
